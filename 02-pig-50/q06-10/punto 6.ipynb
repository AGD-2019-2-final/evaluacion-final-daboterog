# %%
# !rm -rf input output
# !mkdir output

# %%
# %load_ext bigdata

# %%
# %pig_start

# %%
# %timeout 300

# %%
# !hadoop fs -put data.tsv
# Out:
# put: `data.tsv': File exists

# %%
# %%pig
#
# data = LOAD 'data.tsv'
#     AS (f1:CHARARRAY, f2:bag{}, f3:MAP[]);
# DUMP data;
# Out:
#  data = LOAD 'data.tsv'
#     AS (f1:CHARARRAY, f2:bag{}, f3:MAP[]);
#  DUMP data;
# 2019-12-11 01:40:35,289 [main] INFO  org.apache.hadoop.yarn.client.RMProxy - Connecting to ResourceManager at /0.0.0.0:8032
# 2019-12-11 01:40:36,190 [JobControl] INFO  org.apache.hadoop.yarn.client.RMProxy - Connecting to ResourceManager at /0.0.0.0:8032
# 2019-12-11 01:40:36,205 [JobControl] WARN  org.apache.hadoop.mapreduce.JobResourceUploader - No job jar file set.  User classes may not be found. See Job or Job#setJar(String).
# 2019-12-11 01:40:36,212 [JobControl] INFO  org.apache.hadoop.mapreduce.lib.input.FileInputFormat - Total input files to process : 1
# 2019-12-11 01:40:36,244 [JobControl] INFO  org.apache.hadoop.mapreduce.JobSubmitter - number of splits:1
# 2019-12-11 01:40:36,257 [JobControl] INFO  org.apache.hadoop.mapreduce.JobSubmitter - Submitting tokens for job: job_1576021273858_0045
# 2019-12-11 01:40:36,259 [JobControl] INFO  org.apache.hadoop.mapred.YARNRunner - Job jar is not present. Not adding any jar to the list of resources.
# 2019-12-11 01:40:36,290 [JobControl] INFO  org.apache.hadoop.yarn.client.api.impl.YarnClientImpl - Submitted application application_1576021273858_0045
# 2019-12-11 01:40:36,292 [JobControl] INFO  org.apache.hadoop.mapreduce.Job - The url to track the job: http://32aedd3c9786:8088/proxy/application_1576021273858_0045/
# 2019-12-11 01:40:46,747 [main] INFO  org.apache.hadoop.yarn.client.RMProxy - Connecting to ResourceManager at /0.0.0.0:8032
# 2019-12-11 01:40:46,750 [main] INFO  org.apache.hadoop.mapred.ClientServiceDelegate - Application state is completed. FinalApplicationStatus=SUCCEEDED. Redirecting to job history server
# 2019-12-11 01:40:46,791 [main] INFO  org.apache.hadoop.yarn.client.RMProxy - Connecting to ResourceManager at /0.0.0.0:8032
# 2019-12-11 01:40:46,794 [main] INFO  org.apache.hadoop.mapred.ClientServiceDelegate - Application state is completed. FinalApplicationStatus=SUCCEEDED. Redirecting to job history server
# 2019-12-11 01:40:46,809 [main] INFO  org.apache.hadoop.yarn.client.RMProxy - Connecting to ResourceManager at /0.0.0.0:8032
# 2019-12-11 01:40:46,811 [main] INFO  org.apache.hadoop.mapred.ClientServiceDelegate - Application state is completed. FinalApplicationStatus=SUCCEEDED. Redirecting to job history server
# 2019-12-11 01:40:46,827 [main] INFO  org.apache.hadoop.yarn.client.RMProxy - Connecting to ResourceManager at /0.0.0.0:8032
# 2019-12-11 01:40:46,829 [main] INFO  org.apache.hadoop.mapred.ClientServiceDelegate - Application state is completed. FinalApplicationStatus=SUCCEEDED. Redirecting to job history server
# 2019-12-11 01:40:46,846 [main] INFO  org.apache.hadoop.yarn.client.RMProxy - Connecting to ResourceManager at /0.0.0.0:8032
# 2019-12-11 01:40:46,848 [main] INFO  org.apache.hadoop.mapred.ClientServiceDelegate - Application state is completed. FinalApplicationStatus=SUCCEEDED. Redirecting to job history server
# 2019-12-11 01:40:46,862 [main] INFO  org.apache.hadoop.yarn.client.RMProxy - Connecting to ResourceManager at /0.0.0.0:8032
# 2019-12-11 01:40:46,864 [main] INFO  org.apache.hadoop.mapred.ClientServiceDelegate - Application state is completed. FinalApplicationStatus=SUCCEEDED. Redirecting to job history server
# 2019-12-11 01:40:46,884 [main] INFO  org.apache.hadoop.mapreduce.lib.input.FileInputFormat - Total input files to process : 1
# (E,{(b),(g),(f)},[hhh#2,bbb#0,jjj#3,ddd#9,ggg#8])
# (A,{(a),(f),(c)},[aaa#3,hhh#9,ccc#2,ddd#0])
# (B,{(f),(e),(a),(c)},[ccc#6,jjj#1,ddd#2,ggg#5])
# (A,{(a),(b)},[iii#5,hhh#9,bbb#1,eee#7])
# (C,{(f),(g),(d),(a)},[iii#6,jjj#3,eee#4,ddd#5])
# (A,{(c),(d)},[aaa#7,hhh#0,ccc#4,bbb#2,fff#1])
# (A,{(g),(d),(a)},[aaa#5,iii#0,ccc#1,jjj#7,ddd#2,fff#8])
# (B,{(b),(a)},[ddd#2,hhh#1,fff#3])
# (E,{(d),(e),(a),(f)},[iii#9,ccc#5,bbb#0,eee#4,ggg#6,fff#7])
# (B,{(d),(b),(g),(f)},[iii#4,bbb#7,jjj#9,eee#3,ggg#2,fff#5])
# (C,{(d),(c),(f),(b)},[iii#0,hhh#6,jjj#1,eee#4,fff#2])
# (C,{(d),(e),(a),(c)},[iii#6,ggg#9,bbb#7])
# (D,{(g),(e),(f),(b)},[aaa#3,ccc#6,bbb#9,eee#2,fff#4])
# (E,{(c),(f)},[aaa#8,ddd#5,jjj#1])
# (B,{(d),(b)},[aaa#2,ccc#0,jjj#6,ddd#3,fff#7])
# (D,{(f),(e)},[ccc#0,bbb#9,eee#6,ddd#3])
# (E,{(e),(b),(f)},[iii#3,hhh#5,bbb#6,ddd#2,ggg#9,fff#4])
# (D,{(g),(a)},[hhh#4,ccc#9,jjj#5])
# (E,{(e),(c),(f),(a)},[iii#6,ccc#1,fff#9])
# (E,{(e),(a)},[aaa#3,bbb#9,fff#1])
# (E,{(e),(f)},[aaa#4,iii#2,ddd#9])
# (E,{(c),(b),(g)},[iii#7,ccc#5,fff#8])
# (D,{(c),(f),(a)},[eee#3,ddd#7,jjj#2])
# (A,{(f),(a),(d)},[ccc#7,bbb#3,jjj#1,ddd#9,ggg#0])
# (E,{(c),(d)},[aaa#1,iii#7,hhh#9,ccc#0,jjj#6,ggg#8])
# (E,{(e),(d),(c)},[iii#4,ccc#1,bbb#7,eee#6,ddd#0,fff#3])
# (A,{(a),(e),(f)},[ddd#5,ccc#4,fff#0])
# (E,{(c),(a),(g)},[hhh#3,ccc#0,jjj#7,ddd#9,ggg#6])
# (A,{(f),(e)},[iii#7,hhh#6,ccc#3,jjj#0,eee#5])
# (C,{(f),(c),(a),(g)},[aaa#2,ccc#7,eee#1,ddd#6,ggg#0,fff#4])
# (A,{(b),(f)},[aaa#9,ccc#6,bbb#3,eee#5,ddd#0])
# (D,{(b),(f)},[aaa#6,iii#4,hhh#1,bbb#7,ddd#5,fff#9])
# (E,{(a),(c)},[ccc#1,eee#5,ggg#2,fff#3])
# (B,{(b),(f),(c)},[iii#7,hhh#5,ccc#1,jjj#8,ddd#0,ggg#3])
# (B,{(f),(a),(e)},[hhh#6,ccc#3,bbb#8,jjj#0,ddd#7])
# (D,{(a),(f)},[aaa#0,ddd#3,fff#5])
# (B,{(c),(a)},[iii#7,ccc#0,bbb#4,jjj#2,ddd#5])
# (C,{(c),(a),(e),(f)},[eee#0,hhh#6,fff#2])
# (E,{(e),(d)},[eee#0,iii#2,fff#9])
# (E,{(f),(a),(d)},[hhh#8,ggg#3,jjj#5])

# %%
# %%pig
# a = FOREACH data GENERATE FLATTEN(f3) AS f32;
# DUMP a;
# Out:
#  a = FOREACH data GENERATE FLATTEN(f3) AS f32;
#  DUMP a;
# 2019-12-11 01:41:41,086 [main] INFO  org.apache.hadoop.yarn.client.RMProxy - Connecting to ResourceManager at /0.0.0.0:8032
# 2019-12-11 01:41:41,156 [JobControl] INFO  org.apache.hadoop.yarn.client.RMProxy - Connecting to ResourceManager at /0.0.0.0:8032
# 2019-12-11 01:41:41,168 [JobControl] WARN  org.apache.hadoop.mapreduce.JobResourceUploader - No job jar file set.  User classes may not be found. See Job or Job#setJar(String).
# 2019-12-11 01:41:41,174 [JobControl] INFO  org.apache.hadoop.mapreduce.lib.input.FileInputFormat - Total input files to process : 1
# 2019-12-11 01:41:41,999 [JobControl] INFO  org.apache.hadoop.mapreduce.JobSubmitter - number of splits:1
# 2019-12-11 01:41:42,024 [JobControl] INFO  org.apache.hadoop.mapreduce.JobSubmitter - Submitting tokens for job: job_1576021273858_0047
# 2019-12-11 01:41:42,035 [JobControl] INFO  org.apache.hadoop.mapred.YARNRunner - Job jar is not present. Not adding any jar to the list of resources.
# 2019-12-11 01:41:42,062 [JobControl] INFO  org.apache.hadoop.yarn.client.api.impl.YarnClientImpl - Submitted application application_1576021273858_0047
# 2019-12-11 01:41:42,064 [JobControl] INFO  org.apache.hadoop.mapreduce.Job - The url to track the job: http://32aedd3c9786:8088/proxy/application_1576021273858_0047/
# 2019-12-11 01:41:57,132 [main] INFO  org.apache.hadoop.yarn.client.RMProxy - Connecting to ResourceManager at /0.0.0.0:8032
# 2019-12-11 01:41:57,139 [main] INFO  org.apache.hadoop.mapred.ClientServiceDelegate - Application state is completed. FinalApplicationStatus=SUCCEEDED. Redirecting to job history server
# 2019-12-11 01:41:57,180 [main] INFO  org.apache.hadoop.yarn.client.RMProxy - Connecting to ResourceManager at /0.0.0.0:8032
# 2019-12-11 01:41:57,182 [main] INFO  org.apache.hadoop.mapred.ClientServiceDelegate - Application state is completed. FinalApplicationStatus=SUCCEEDED. Redirecting to job history server
# 2019-12-11 01:41:57,198 [main] INFO  org.apache.hadoop.yarn.client.RMProxy - Connecting to ResourceManager at /0.0.0.0:8032
# 2019-12-11 01:41:57,200 [main] INFO  org.apache.hadoop.mapred.ClientServiceDelegate - Application state is completed. FinalApplicationStatus=SUCCEEDED. Redirecting to job history server
# 2019-12-11 01:41:57,214 [main] INFO  org.apache.hadoop.yarn.client.RMProxy - Connecting to ResourceManager at /0.0.0.0:8032
# 2019-12-11 01:41:57,217 [main] INFO  org.apache.hadoop.mapred.ClientServiceDelegate - Application state is completed. FinalApplicationStatus=SUCCEEDED. Redirecting to job history server
# 2019-12-11 01:41:57,232 [main] INFO  org.apache.hadoop.yarn.client.RMProxy - Connecting to ResourceManager at /0.0.0.0:8032
# 2019-12-11 01:41:57,235 [main] INFO  org.apache.hadoop.mapred.ClientServiceDelegate - Application state is completed. FinalApplicationStatus=SUCCEEDED. Redirecting to job history server
# 2019-12-11 01:41:57,249 [main] INFO  org.apache.hadoop.yarn.client.RMProxy - Connecting to ResourceManager at /0.0.0.0:8032
# 2019-12-11 01:41:57,251 [main] INFO  org.apache.hadoop.mapred.ClientServiceDelegate - Application state is completed. FinalApplicationStatus=SUCCEEDED. Redirecting to job history server
# 2019-12-11 01:41:57,272 [main] INFO  org.apache.hadoop.mapreduce.lib.input.FileInputFormat - Total input files to process : 1
# (bbb,0)
# (ddd,9)
# (ggg,8)
# (hhh,2)
# (jjj,3)
# (aaa,3)
# (ccc,2)
# (ddd,0)
# (hhh,9)
# (ccc,6)
# (ddd,2)
# (ggg,5)
# (jjj,1)
# (bbb,1)
# (eee,7)
# (iii,5)
# (hhh,9)
# (eee,4)
# (ddd,5)
# (iii,6)
# (jjj,3)
# (aaa,7)
# (ccc,4)
# (bbb,2)
# (fff,1)
# (hhh,0)
# (aaa,5)
# (ccc,1)
# (ddd,2)
# (fff,8)
# (iii,0)
# (jjj,7)
# (ddd,2)
# (fff,3)
# (hhh,1)
# (ccc,5)
# (bbb,0)
# (eee,4)
# (ggg,6)
# (fff,7)
# (iii,9)
# (bbb,7)
# (eee,3)
# (ggg,2)
# (fff,5)
# (iii,4)
# (jjj,9)
# (eee,4)
# (fff,2)
# (iii,0)
# (hhh,6)
# (jjj,1)
# (bbb,7)
# (ggg,9)
# (iii,6)
# (aaa,3)
# (ccc,6)
# (bbb,9)
# (eee,2)
# (fff,4)
# (aaa,8)
# (ddd,5)
# (jjj,1)
# (aaa,2)
# (ccc,0)
# (ddd,3)
# (fff,7)
# (jjj,6)
# (ccc,0)
# (bbb,9)
# (eee,6)
# (ddd,3)
# (bbb,6)
# (ddd,2)
# (ggg,9)
# (fff,4)
# (iii,3)
# (hhh,5)
# (ccc,9)
# (hhh,4)
# (jjj,5)
# (ccc,1)
# (fff,9)
# (iii,6)
# (aaa,3)
# (bbb,9)
# (fff,1)
# (aaa,4)
# (ddd,9)
# (iii,2)
# (ccc,5)
# (fff,8)
# (iii,7)
# (eee,3)
# (ddd,7)
# (jjj,2)
# (ccc,7)
# (bbb,3)
# (ddd,9)
# (ggg,0)
# (jjj,1)
# (aaa,1)
# (ccc,0)
# (ggg,8)
# (iii,7)
# (hhh,9)
# (jjj,6)
# (ccc,1)
# (bbb,7)
# (eee,6)
# (ddd,0)
# (fff,3)
# (iii,4)
# (ccc,4)
# (ddd,5)
# (fff,0)
# (ccc,0)
# (ddd,9)
# (ggg,6)
# (hhh,3)
# (jjj,7)
# (ccc,3)
# (eee,5)
# (iii,7)
# (hhh,6)
# (jjj,0)
# (aaa,2)
# (ccc,7)
# (eee,1)
# (ddd,6)
# (ggg,0)
# (fff,4)
# (aaa,9)
# (ccc,6)
# (bbb,3)
# (eee,5)
# (ddd,0)
# (aaa,6)
# (bbb,7)
# (ddd,5)
# (fff,9)
# (iii,4)
# (hhh,1)
# (ccc,1)
# (eee,5)
# (ggg,2)
# (fff,3)
# (ccc,1)
# (ddd,0)
# (ggg,3)
# (iii,7)
# (hhh,5)
# (jjj,8)
# (ccc,3)
# (bbb,8)
# (ddd,7)
# (hhh,6)
# (jjj,0)
# (aaa,0)
# (ddd,3)
# (fff,5)
# (ccc,0)
# (bbb,4)
# (ddd,5)
# (iii,7)
# (jjj,2)
# (eee,0)
# (fff,2)
# (hhh,6)
# (eee,0)
# (fff,9)
# (iii,2)
# (ggg,3)
# (hhh,8)
# (jjj,5)

# %%
# %%pig
# b = GROUP a BY f32;
# DUMP b;
# Out:
#  b = GROUP a BY f32;
#  DUMP b;
# 2019-12-11 01:45:50,512 [main] INFO  org.apache.hadoop.yarn.client.RMProxy - Connecting to ResourceManager at /0.0.0.0:8032
# 2019-12-11 01:45:51,048 [JobControl] INFO  org.apache.hadoop.yarn.client.RMProxy - Connecting to ResourceManager at /0.0.0.0:8032
# 2019-12-11 01:45:51,063 [JobControl] WARN  org.apache.hadoop.mapreduce.JobResourceUploader - No job jar file set.  User classes may not be found. See Job or Job#setJar(String).
# 2019-12-11 01:45:51,071 [JobControl] INFO  org.apache.hadoop.mapreduce.lib.input.FileInputFormat - Total input files to process : 1
# 2019-12-11 01:45:51,094 [JobControl] INFO  org.apache.hadoop.mapreduce.JobSubmitter - number of splits:1
# 2019-12-11 01:45:51,106 [JobControl] INFO  org.apache.hadoop.mapreduce.JobSubmitter - Submitting tokens for job: job_1576021273858_0048
# 2019-12-11 01:45:51,108 [JobControl] INFO  org.apache.hadoop.mapred.YARNRunner - Job jar is not present. Not adding any jar to the list of resources.
# 2019-12-11 01:45:51,130 [JobControl] INFO  org.apache.hadoop.yarn.client.api.impl.YarnClientImpl - Submitted application application_1576021273858_0048
# 2019-12-11 01:45:51,132 [JobControl] INFO  org.apache.hadoop.mapreduce.Job - The url to track the job: http://32aedd3c9786:8088/proxy/application_1576021273858_0048/
# 2019-12-11 01:46:11,597 [main] INFO  org.apache.hadoop.yarn.client.RMProxy - Connecting to ResourceManager at /0.0.0.0:8032
# 2019-12-11 01:46:11,602 [main] INFO  org.apache.hadoop.mapred.ClientServiceDelegate - Application state is completed. FinalApplicationStatus=SUCCEEDED. Redirecting to job history server
# 2019-12-11 01:46:11,677 [main] INFO  org.apache.hadoop.yarn.client.RMProxy - Connecting to ResourceManager at /0.0.0.0:8032
# 2019-12-11 01:46:11,680 [main] INFO  org.apache.hadoop.mapred.ClientServiceDelegate - Application state is completed. FinalApplicationStatus=SUCCEEDED. Redirecting to job history server
# 2019-12-11 01:46:11,714 [main] INFO  org.apache.hadoop.yarn.client.RMProxy - Connecting to ResourceManager at /0.0.0.0:8032
# 2019-12-11 01:46:11,717 [main] INFO  org.apache.hadoop.mapred.ClientServiceDelegate - Application state is completed. FinalApplicationStatus=SUCCEEDED. Redirecting to job history server
# 2019-12-11 01:46:11,749 [main] INFO  org.apache.hadoop.yarn.client.RMProxy - Connecting to ResourceManager at /0.0.0.0:8032
# 2019-12-11 01:46:11,752 [main] INFO  org.apache.hadoop.mapred.ClientServiceDelegate - Application state is completed. FinalApplicationStatus=SUCCEEDED. Redirecting to job history server
# 2019-12-11 01:46:11,782 [main] INFO  org.apache.hadoop.yarn.client.RMProxy - Connecting to ResourceManager at /0.0.0.0:8032
# 2019-12-11 01:46:11,786 [main] INFO  org.apache.hadoop.mapred.ClientServiceDelegate - Application state is completed. FinalApplicationStatus=SUCCEEDED. Redirecting to job history server
# 2019-12-11 01:46:11,824 [main] INFO  org.apache.hadoop.yarn.client.RMProxy - Connecting to ResourceManager at /0.0.0.0:8032
# 2019-12-11 01:46:11,828 [main] INFO  org.apache.hadoop.mapred.ClientServiceDelegate - Application state is completed. FinalApplicationStatus=SUCCEEDED. Redirecting to job history server
# 2019-12-11 01:46:11,864 [main] INFO  org.apache.hadoop.mapreduce.lib.input.FileInputFormat - Total input files to process : 1
# (aaa,{(aaa,6),(aaa,0),(aaa,7),(aaa,5),(aaa,3),(aaa,8),(aaa,2),(aaa,3),(aaa,4),(aaa,1),(aaa,2),(aaa,9),(aaa,3)})
# (bbb,{(bbb,0),(bbb,4),(bbb,8),(bbb,7),(bbb,3),(bbb,7),(bbb,3),(bbb,9),(bbb,6),(bbb,9),(bbb,9),(bbb,7),(bbb,7),(bbb,0),(bbb,2),(bbb,1)})
# (ccc,{(ccc,3),(ccc,2),(ccc,0),(ccc,1),(ccc,9),(ccc,6),(ccc,1),(ccc,7),(ccc,4),(ccc,3),(ccc,1),(ccc,0),(ccc,1),(ccc,4),(ccc,1),(ccc,5),(ccc,0),(ccc,6),(ccc,6),(ccc,7),(ccc,0),(ccc,5),(ccc,0)})
# (ddd,{(ddd,2),(ddd,0),(ddd,5),(ddd,7),(ddd,7),(ddd,5),(ddd,5),(ddd,3),(ddd,6),(ddd,2),(ddd,0),(ddd,0),(ddd,9),(ddd,5),(ddd,2),(ddd,9),(ddd,3),(ddd,2),(ddd,9),(ddd,9),(ddd,3),(ddd,5),(ddd,0)})
# (eee,{(eee,5),(eee,6),(eee,3),(eee,0),(eee,4),(eee,3),(eee,6),(eee,4),(eee,5),(eee,5),(eee,1),(eee,2),(eee,7),(eee,4),(eee,0)})
# (fff,{(fff,3),(fff,9),(fff,4),(fff,0),(fff,3),(fff,8),(fff,1),(fff,2),(fff,9),(fff,4),(fff,7),(fff,4),(fff,9),(fff,2),(fff,5),(fff,7),(fff,3),(fff,8),(fff,1),(fff,5)})
# (ggg,{(ggg,8),(ggg,3),(ggg,9),(ggg,6),(ggg,9),(ggg,2),(ggg,0),(ggg,3),(ggg,5),(ggg,8),(ggg,2),(ggg,0),(ggg,6)})
# (hhh,{(hhh,9),(hhh,2),(hhh,4),(hhh,9),(hhh,1),(hhh,5),(hhh,8),(hhh,1),(hhh,6),(hhh,6),(hhh,9),(hhh,3),(hhh,6),(hhh,0),(hhh,5),(hhh,6)})
# (iii,{(iii,7),(iii,6),(iii,0),(iii,4),(iii,7),(iii,9),(iii,7),(iii,4),(iii,0),(iii,4),(iii,2),(iii,7),(iii,6),(iii,5),(iii,7),(iii,3),(iii,6),(iii,2)})
# (jjj,{(jjj,0),(jjj,8),(jjj,1),(jjj,2),(jjj,1),(jjj,3),(jjj,0),(jjj,1),(jjj,2),(jjj,6),(jjj,1),(jjj,7),(jjj,7),(jjj,5),(jjj,6),(jjj,3),(jjj,5),(jjj,9)})

# %%
# %%pig
# c = FOREACH b GENERATE group, COUNT(a);
# DUMP c;
# Out:
#  c = FOREACH b GENERATE group, COUNT(a);
#  DUMP c;
# 2019-12-11 01:47:28,155 [main] INFO  org.apache.hadoop.yarn.client.RMProxy - Connecting to ResourceManager at /0.0.0.0:8032
# 2019-12-11 01:47:28,271 [JobControl] INFO  org.apache.hadoop.yarn.client.RMProxy - Connecting to ResourceManager at /0.0.0.0:8032
# 2019-12-11 01:47:28,288 [JobControl] WARN  org.apache.hadoop.mapreduce.JobResourceUploader - No job jar file set.  User classes may not be found. See Job or Job#setJar(String).
# 2019-12-11 01:47:28,295 [JobControl] INFO  org.apache.hadoop.mapreduce.lib.input.FileInputFormat - Total input files to process : 1
# 2019-12-11 01:47:28,723 [JobControl] INFO  org.apache.hadoop.mapreduce.JobSubmitter - number of splits:1
# 2019-12-11 01:47:28,737 [JobControl] INFO  org.apache.hadoop.mapreduce.JobSubmitter - Submitting tokens for job: job_1576021273858_0049
# 2019-12-11 01:47:28,739 [JobControl] INFO  org.apache.hadoop.mapred.YARNRunner - Job jar is not present. Not adding any jar to the list of resources.
# 2019-12-11 01:47:28,761 [JobControl] INFO  org.apache.hadoop.yarn.client.api.impl.YarnClientImpl - Submitted application application_1576021273858_0049
# 2019-12-11 01:47:28,764 [JobControl] INFO  org.apache.hadoop.mapreduce.Job - The url to track the job: http://32aedd3c9786:8088/proxy/application_1576021273858_0049/
# 2019-12-11 01:47:48,874 [main] INFO  org.apache.hadoop.yarn.client.RMProxy - Connecting to ResourceManager at /0.0.0.0:8032
# 2019-12-11 01:47:48,881 [main] INFO  org.apache.hadoop.mapred.ClientServiceDelegate - Application state is completed. FinalApplicationStatus=SUCCEEDED. Redirecting to job history server
# 2019-12-11 01:47:48,946 [main] INFO  org.apache.hadoop.yarn.client.RMProxy - Connecting to ResourceManager at /0.0.0.0:8032
# 2019-12-11 01:47:48,951 [main] INFO  org.apache.hadoop.mapred.ClientServiceDelegate - Application state is completed. FinalApplicationStatus=SUCCEEDED. Redirecting to job history server
# 2019-12-11 01:47:48,987 [main] INFO  org.apache.hadoop.yarn.client.RMProxy - Connecting to ResourceManager at /0.0.0.0:8032
# 2019-12-11 01:47:48,989 [main] INFO  org.apache.hadoop.mapred.ClientServiceDelegate - Application state is completed. FinalApplicationStatus=SUCCEEDED. Redirecting to job history server
# 2019-12-11 01:47:49,014 [main] INFO  org.apache.hadoop.yarn.client.RMProxy - Connecting to ResourceManager at /0.0.0.0:8032
# 2019-12-11 01:47:49,017 [main] INFO  org.apache.hadoop.mapred.ClientServiceDelegate - Application state is completed. FinalApplicationStatus=SUCCEEDED. Redirecting to job history server
# 2019-12-11 01:47:49,040 [main] INFO  org.apache.hadoop.yarn.client.RMProxy - Connecting to ResourceManager at /0.0.0.0:8032
# 2019-12-11 01:47:49,042 [main] INFO  org.apache.hadoop.mapred.ClientServiceDelegate - Application state is completed. FinalApplicationStatus=SUCCEEDED. Redirecting to job history server
# 2019-12-11 01:47:49,064 [main] INFO  org.apache.hadoop.yarn.client.RMProxy - Connecting to ResourceManager at /0.0.0.0:8032
# 2019-12-11 01:47:49,068 [main] INFO  org.apache.hadoop.mapred.ClientServiceDelegate - Application state is completed. FinalApplicationStatus=SUCCEEDED. Redirecting to job history server
# 2019-12-11 01:47:49,095 [main] INFO  org.apache.hadoop.mapreduce.lib.input.FileInputFormat - Total input files to process : 1
# (aaa,13)
# (bbb,16)
# (ccc,23)
# (ddd,23)
# (eee,15)
# (fff,20)
# (ggg,13)
# (hhh,16)
# (iii,18)
# (jjj,18)

# %%
# %%pig
# STORE c INTO 'output';
# fs -get output/ .
# Out:
#  STORE c INTO 'output';
# 2019-12-11 01:48:33,480 [main] INFO  org.apache.hadoop.conf.Configuration.deprecation - mapred.textoutputformat.separator is deprecated. Instead, use mapreduce.output.textoutputformat.separator
# 2019-12-11 01:48:33,487 [main] ERROR org.apache.pig.tools.grunt.Grunt - ERROR 6000: <line 11, column 0> Output Location Validation Failed for: 'hdfs://0.0.0.0:9000/user/root/output More info to follow:
# Output directory hdfs://0.0.0.0:9000/user/root/output already exists
# Details at logfile: /datalake/evaluacion-final-daboterog/02-pig-50/q06-10/pig_1576028259712.log
#  fs -get output/ .
